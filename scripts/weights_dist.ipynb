# %%
from nanugpt import utils
import numpy as np

# %%
weights_filepaths = r"C:\Users\shitals\out_dir\grokking\seed42_8_weights.npy"

# %%
weights = np.load(weights_filepaths, allow_pickle=True)
utils.draw_histogram(weights, title="Weights distribution")

# %%
weights_filepaths = r"C:\Users\shitals\out_dir\grokking\seed56_7_weights.npy"
weights = np.load(weights_filepaths, allow_pickle=True)
utils.draw_histogram(weights, title="Weights distribution")
